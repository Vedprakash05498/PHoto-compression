# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
img=plt.imread("2.jpg")
plt.imshow(img)

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
img=plt.imread("3.jpg")
plt.imshow(img)

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
img=plt.imread("4.jpeg")
plt.imshow(img)
